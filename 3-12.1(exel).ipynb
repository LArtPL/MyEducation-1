# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_excel('module3_Fig3-1.xls', header=None)

# %%
data
# Out:
#                                                     0        1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...      NaN  NaN
# 1                See the book for description of data.      NaN  NaN
# 2    Monthly data from January 1953 for prices, all...      NaN  NaN
# 3                                                  NaN     Real  NaN
# 4                                                  NaN     Home  NaN
# ..                                                 ...      ...  ...
# 859                                            2018.79  174.056  NaN
# 860                                            2018.87  174.439  NaN
# 861                                            2018.96  174.659  NaN
# 862                                            2019.04  174.016  NaN
# 863                                                NaN      NaN  NaN
#
#            3                                                  4    5    6   \
# 0         NaN                                                NaN  NaN  NaN
# 1         NaN  Update Nominal Home Price Index, Click Additio...  NaN  NaN
# 2         NaN                                                NaN  NaN  NaN
# 3        Real                                                NaN  NaN  NaN
# 4    Building                                               U.S.  NaN  NaN
# ..        ...                                                ...  ...  ...
# 859       NaN                                                NaN  NaN  NaN
# 860       NaN                                                NaN  NaN  NaN
# 861       NaN                                                NaN  NaN  NaN
# 862       NaN                                                NaN  NaN  NaN
# 863       NaN                                                NaN  NaN  NaN
#
#           7        8                           9    10        11   12  \
# 0        NaN      NaN                         NaN  NaN       NaN  NaN
# 1        NaN      NaN                         NaN  NaN       NaN  NaN
# 2        NaN  Nominal                         NaN  NaN       NaN  NaN
# 3        NaN     Home                         NaN  NaN   Nominal  NaN
# 4        NaN    Price                         HPI  NaN  Building  NaN
# ..       ...      ...                         ...  ...       ...  ...
# 859  2018.79  205.709  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 860  2018.87  205.471  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 861  2018.96  205.073  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 862  2019.04  204.708  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 863      NaN      NaN                         NaN  NaN       NaN  NaN
#
#           13        14           15  16   17   18
# 0        NaN       NaN          NaN NaN  NaN  NaN
# 1        NaN       NaN          NaN NaN  NaN  NaN
# 2        NaN       NaN          NaN NaN  NaN  NaN
# 3        NaN  Consumer          NaN NaN  NaN  NaN
# 4        NaN     Price  CPI Annual& NaN  NaN  NaN
# ..       ...       ...          ...  ..  ...  ...
# 859  2018.79   252.885          BLS NaN  NaN  NaN
# 860  2018.87   252.038          BLS NaN  NaN  NaN
# 861  2018.96   251.233          BLS NaN  NaN  NaN
# 862  2019.04   251.712          BLS NaN  NaN  NaN
# 863  2019.12   252.776          BLS NaN  NaN  NaN
#
# [864 rows x 19 columns]

# %%
data_file = pd.ExcelFile('./module3_Fig3-1.xls')  
data = pd.read_excel(data_file, header=None)

# %%
data
# Out:
#                                                     0        1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...      NaN  NaN
# 1                See the book for description of data.      NaN  NaN
# 2    Monthly data from January 1953 for prices, all...      NaN  NaN
# 3                                                  NaN     Real  NaN
# 4                                                  NaN     Home  NaN
# ..                                                 ...      ...  ...
# 859                                            2018.79  174.056  NaN
# 860                                            2018.87  174.439  NaN
# 861                                            2018.96  174.659  NaN
# 862                                            2019.04  174.016  NaN
# 863                                                NaN      NaN  NaN
#
#            3                                                  4    5    6   \
# 0         NaN                                                NaN  NaN  NaN
# 1         NaN  Update Nominal Home Price Index, Click Additio...  NaN  NaN
# 2         NaN                                                NaN  NaN  NaN
# 3        Real                                                NaN  NaN  NaN
# 4    Building                                               U.S.  NaN  NaN
# ..        ...                                                ...  ...  ...
# 859       NaN                                                NaN  NaN  NaN
# 860       NaN                                                NaN  NaN  NaN
# 861       NaN                                                NaN  NaN  NaN
# 862       NaN                                                NaN  NaN  NaN
# 863       NaN                                                NaN  NaN  NaN
#
#           7        8                           9    10        11   12  \
# 0        NaN      NaN                         NaN  NaN       NaN  NaN
# 1        NaN      NaN                         NaN  NaN       NaN  NaN
# 2        NaN  Nominal                         NaN  NaN       NaN  NaN
# 3        NaN     Home                         NaN  NaN   Nominal  NaN
# 4        NaN    Price                         HPI  NaN  Building  NaN
# ..       ...      ...                         ...  ...       ...  ...
# 859  2018.79  205.709  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 860  2018.87  205.471  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 861  2018.96  205.073  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 862  2019.04  204.708  S&P/CoreLogic/Case-Shiller  NaN       NaN  NaN
# 863      NaN      NaN                         NaN  NaN       NaN  NaN
#
#           13        14           15  16   17   18
# 0        NaN       NaN          NaN NaN  NaN  NaN
# 1        NaN       NaN          NaN NaN  NaN  NaN
# 2        NaN       NaN          NaN NaN  NaN  NaN
# 3        NaN  Consumer          NaN NaN  NaN  NaN
# 4        NaN     Price  CPI Annual& NaN  NaN  NaN
# ..       ...       ...          ...  ..  ...  ...
# 859  2018.79   252.885          BLS NaN  NaN  NaN
# 860  2018.87   252.038          BLS NaN  NaN  NaN
# 861  2018.96   251.233          BLS NaN  NaN  NaN
# 862  2019.04   251.712          BLS NaN  NaN  NaN
# 863  2019.12   252.776          BLS NaN  NaN  NaN
#
# [864 rows x 19 columns]

# %% [markdown]
# Если мы просто хотим прочитать два листа из Excel-файла, то этот код:
#
# with pd.ExcelFile('path_to_file.xls') as xls:
#     data['Sheet1'] = pd.read_excel(xls, 'Sheet1')
#     data['Sheet2'] = pd.read_excel(xls, 'Sheet2')
# И этот код:
#
# data = pd.read_excel('path_to_file.xls', ['Sheet1', 'Sheet2'])
# Оба кода дадут нам одинаковый результат как по скорости работы, так и по возвращаемому результату.

# %%
data = pd.read_excel('http://www.econ.yale.edu/~shiller/data/Fig3-1.xls', header=None)

# %%
data
# Out:
#                                                     0        1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...      NaN  NaN
# 1                See the book for description of data.      NaN  NaN
# 2    Monthly data from January 1953 for prices, all...      NaN  NaN
# 3                                                  NaN     Real  NaN
# 4                                                  NaN     Home  NaN
# ..                                                 ...      ...  ...
# 866                                            2019.37  175.147  NaN
# 867                                            2019.46  176.131  NaN
# 868                                            2019.54  176.456  NaN
# 869                                            2019.62  176.767  NaN
# 870                                            2019.71  176.842  NaN
#
#            3                                                  4    5    6   \
# 0         NaN                                                NaN  NaN  NaN
# 1         NaN  Update Nominal Home Price Index, Click Additio...  NaN  NaN
# 2         NaN                                                NaN  NaN  NaN
# 3        Real                                                NaN  NaN  NaN
# 4    Building                                               U.S.  NaN  NaN
# ..        ...                                                ...  ...  ...
# 866       NaN                                                NaN  NaN  NaN
# 867       NaN                                                NaN  NaN  NaN
# 868       NaN                                                NaN  NaN  NaN
# 869       NaN                                                NaN  NaN  NaN
# 870       NaN                                                NaN  NaN  NaN
#
#           7        8    9    10        11   12       13        14  \
# 0        NaN      NaN  NaN  NaN       NaN  NaN      NaN       NaN
# 1        NaN      NaN  NaN  NaN       NaN  NaN      NaN       NaN
# 2        NaN  Nominal  NaN  NaN       NaN  NaN      NaN       NaN
# 3        NaN     Home  NaN  NaN   Nominal  NaN      NaN  Consumer
# 4        NaN    Price  HPI  NaN  Building  NaN      NaN     Price
# ..       ...      ...  ...  ...       ...  ...      ...       ...
# 866  2019.37  209.624  NaN  NaN       NaN  NaN  2019.37   256.092
# 867  2019.46  210.843  NaN  NaN       NaN  NaN  2019.46   256.143
# 868  2019.54  211.585  NaN  NaN       NaN  NaN  2019.54   256.571
# 869  2019.62  211.947  NaN  NaN       NaN  NaN  2019.62   256.558
# 870  2019.71  212.203  NaN  NaN       NaN  NaN  2019.71   256.759
#
#               15  16   17   18
# 0            NaN NaN  NaN  NaN
# 1            NaN NaN  NaN  NaN
# 2            NaN NaN  NaN  NaN
# 3            NaN NaN  NaN  NaN
# 4    CPI Annual& NaN  NaN  NaN
# ..           ...  ..  ...  ...
# 866          BLS NaN  NaN  NaN
# 867          BLS NaN  NaN  NaN
# 868          BLS NaN  NaN  NaN
# 869          BLS NaN  NaN  NaN
# 870          BLS NaN  NaN  NaN
#
# [871 rows x 19 columns]

# %%
data = pd.read_excel("./module3_nakladnaya.xls", header=None, skiprows=2)

# %%
data
# Out:
#     0                                  1   \
# 0  NaN                                NaN
# 1  NaN                                NaN
# 2  NaN                  Грузоотправитель:
# 3  NaN                                NaN
# 4  NaN                   Грузополучатель:
# 5  NaN                                NaN
# 6  NaN  Основание для отпуска: Договор №
# 7  NaN                                NaN
# 8  NaN                                NaN
# 9  NaN                                  №
# 10 NaN                                п/п
# 11 NaN                                  1
# 12 NaN                                  2
# 13 NaN                                NaN
# 14 NaN                                NaN
# 15 NaN                                NaN
# 16 NaN                                NaN
# 17 NaN                                NaN
# 18 NaN                                NaN
# 19 NaN                                NaN
# 20 NaN                                NaN
# 21 NaN                                NaN
# 22 NaN                                NaN
# 23 NaN                                NaN
# 24 NaN                                NaN
# 25 NaN                                NaN
#
#                                              2   \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9   Наименование товарно-материальных ценностей
# 10                                          NaN
# 11                        Велосипед "Спринтер"
# 12                          Велосипед "Малютка"
# 13                                          NaN
# 14                              Всего отпущено
# 15                                          NaN
# 16                                   На сумму
# 17                                          NaN
# 18                            Отпуск разрешил
# 19                                          NaN
# 20                                         М.П.
# 21                                          NaN
# 22                                   Отпустил
# 23                                    Получил
# 24                                          NaN
# 25                                         М.П.
#
#                                    3                                  4   \
# 0                           НАКЛАДНАЯ  № 5764809  от "08" апреля 2018 г.
# 1                                 NaN                                NaN
# 2              ООО "Первый строитель"                                NaN
# 3                                 NaN                                NaN
# 4                 ООО "Стройка века"                                 NaN
# 5                                 NaN                                NaN
# 6                                 NaN                                 86
# 7                                 NaN                                NaN
# 8                                 NaN                                NaN
# 9                                 NaN                                NaN
# 10                                NaN                                NaN
# 11                                NaN                                NaN
# 12                                NaN                                NaN
# 13                                NaN                                NaN
# 14               2 (два) наименования                                NaN
# 15                                NaN                                NaN
# 16  80 000 (восемьдесят тысяч) рублей                                NaN
# 17                                NaN                                NaN
# 18                     Зам. Директора                                NaN
# 19                                NaN                                NaN
# 20                                NaN                                NaN
# 21                                NaN                                NaN
# 22                         Кладовщик                                 NaN
# 23                          Водитель                                 NaN
# 24                                NaN                                NaN
# 25                                NaN                                NaN
#
#                        5         6   7          8           9   10  \
# 0                     NaN       NaN NaN        NaN         NaN NaN
# 1                     NaN       NaN NaN        NaN         NaN NaN
# 2                     NaN       NaN NaN        NaN         NaN NaN
# 3                     NaN       NaN NaN        NaN         NaN NaN
# 4                     NaN       NaN NaN        NaN         NaN NaN
# 5                     NaN       NaN NaN        NaN         NaN NaN
# 6   от "02"апреля 2018 г.       NaN NaN        NaN         NaN NaN
# 7                     NaN       NaN NaN        NaN         NaN NaN
# 8                     NaN       NaN NaN        NaN         NaN NaN
# 9                     NaN  Ед. изм. NaN        NaN  Количество NaN
# 10                    NaN       NaN NaN        NaN         NaN NaN
# 11                    NaN        шт NaN        NaN           5 NaN
# 12                    NaN        шт NaN        NaN          10 NaN
# 13                    NaN       NaN NaN        NaN         NaN NaN
# 14                    NaN       NaN NaN        NaN         NaN NaN
# 15                    NaN       NaN NaN        NaN         NaN NaN
# 16                    NaN       NaN NaN        NaN         NaN NaN
# 17                    NaN       NaN NaN        NaN         NaN NaN
# 18                    NaN       NaN NaN    Куликов         NaN NaN
# 19                    NaN       NaN NaN        NaN         NaN NaN
# 20                    NaN       NaN NaN        NaN         NaN NaN
# 21                    NaN       NaN NaN        NaN         NaN NaN
# 22                    NaN       NaN NaN      Мазов         NaN NaN
# 23                    NaN       NaN NaN  Дроценко          NaN NaN
# 24                    NaN       NaN NaN        NaN         NaN NaN
# 25                    NaN       NaN NaN        NaN         NaN NaN
#
#                 11         12
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# 5              NaN        NaN
# 6              NaN        NaN
# 7              NaN        NaN
# 8              NaN        NaN
# 9           Цена,     Сумма,
# 10       руб. коп.  руб. коп.
# 11            9000      45000
# 12            3500      35000
# 13             NaN        NaN
# 14             NaN        NaN
# 15             NaN        NaN
# 16             NaN        NaN
# 17             NaN        NaN
# 18   Куликов П.Д.         NaN
# 19             NaN        NaN
# 20             NaN        NaN
# 21             NaN        NaN
# 22      Мазов Р.К.        NaN
# 23  Дроценко А.С.         NaN
# 24             NaN        NaN
# 25             NaN        NaN

# %%
len(data.dropna(how='all'))
# Out:
# 15

# %%
data2 = data.dropna(how='all')

# %%
data2 = data2.dropna(axis=1, how='all')

# %%
len(data2.columns)
# Out:
# 10

# %%
data2
# Out:
#                                    1   \
# 0                                 NaN
# 2                   Грузоотправитель:
# 4                    Грузополучатель:
# 6   Основание для отпуска: Договор №
# 9                                   №
# 10                                п/п
# 11                                  1
# 12                                  2
# 14                                NaN
# 16                                NaN
# 18                                NaN
# 20                                NaN
# 22                                NaN
# 23                                NaN
# 25                                NaN
#
#                                              2   \
# 0                                           NaN
# 2                                           NaN
# 4                                           NaN
# 6                                           NaN
# 9   Наименование товарно-материальных ценностей
# 10                                          NaN
# 11                        Велосипед "Спринтер"
# 12                          Велосипед "Малютка"
# 14                              Всего отпущено
# 16                                   На сумму
# 18                            Отпуск разрешил
# 20                                         М.П.
# 22                                   Отпустил
# 23                                    Получил
# 25                                         М.П.
#
#                                    3                                  4   \
# 0                           НАКЛАДНАЯ  № 5764809  от "08" апреля 2018 г.
# 2              ООО "Первый строитель"                                NaN
# 4                 ООО "Стройка века"                                 NaN
# 6                                 NaN                                 86
# 9                                 NaN                                NaN
# 10                                NaN                                NaN
# 11                                NaN                                NaN
# 12                                NaN                                NaN
# 14               2 (два) наименования                                NaN
# 16  80 000 (восемьдесят тысяч) рублей                                NaN
# 18                     Зам. Директора                                NaN
# 20                                NaN                                NaN
# 22                         Кладовщик                                 NaN
# 23                          Водитель                                 NaN
# 25                                NaN                                NaN
#
#                        5         6          8           9               11  \
# 0                     NaN       NaN        NaN         NaN             NaN
# 2                     NaN       NaN        NaN         NaN             NaN
# 4                     NaN       NaN        NaN         NaN             NaN
# 6   от "02"апреля 2018 г.       NaN        NaN         NaN             NaN
# 9                     NaN  Ед. изм.        NaN  Количество          Цена,
# 10                    NaN       NaN        NaN         NaN       руб. коп.
# 11                    NaN        шт        NaN           5            9000
# 12                    NaN        шт        NaN          10            3500
# 14                    NaN       NaN        NaN         NaN             NaN
# 16                    NaN       NaN        NaN         NaN             NaN
# 18                    NaN       NaN    Куликов         NaN   Куликов П.Д.
# 20                    NaN       NaN        NaN         NaN             NaN
# 22                    NaN       NaN      Мазов         NaN      Мазов Р.К.
# 23                    NaN       NaN  Дроценко          NaN  Дроценко А.С.
# 25                    NaN       NaN        NaN         NaN             NaN
#
#            12
# 0         NaN
# 2         NaN
# 4         NaN
# 6         NaN
# 9     Сумма,
# 10  руб. коп.
# 11      45000
# 12      35000
# 14        NaN
# 16        NaN
# 18        NaN
# 20        NaN
# 22        NaN
# 23        NaN
# 25        NaN

# %%
data2.iloc[6:8, [1, 2, 6, 9, 11, 12]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-3ed87387c100> in <module>
# ----> 1 data2.iloc[6:8, [1, 2, 6, 9, 11, 12]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2065     def _getitem_tuple(self, tup: Tuple):
#    2066
# -> 2067         self._has_valid_tuple(tup)
#    2068         try:
#    2069             return self._getitem_lowerdim(tup)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     701                 raise IndexingError("Too many indexers")
#     702             try:
# --> 703                 self._validate_key(k, i)
#     704             except ValueError:
#     705                 raise ValueError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    2007             # check that the key does not exceed the maximum size of the index
#    2008             if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 2009                 raise IndexError("positional indexers are out-of-bounds")
#    2010         else:
#    2011             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %%
data2.iloc[6:8, [0, 2, 6, 9, 11, 12]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-44d35a880ac8> in <module>
# ----> 1 data2.iloc[6:8, [0, 2, 6, 9, 11, 12]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2065     def _getitem_tuple(self, tup: Tuple):
#    2066
# -> 2067         self._has_valid_tuple(tup)
#    2068         try:
#    2069             return self._getitem_lowerdim(tup)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     701                 raise IndexingError("Too many indexers")
#     702             try:
# --> 703                 self._validate_key(k, i)
#     704             except ValueError:
#     705                 raise ValueError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    2007             # check that the key does not exceed the maximum size of the index
#    2008             if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 2009                 raise IndexError("positional indexers are out-of-bounds")
#    2010         else:
#    2011             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %%
data2.iloc[7:8, :].dropna(axis=1, how='all')
# Out:
#    1                    2   6   9     11     12
# 12  2  Велосипед "Малютка"  шт  10  3500  35000

# %%
data2.iloc[6:8, :].dropna(axis=1, how='any')
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000

# %%
data2.iloc[6:8, :].dropna(axis=1, how='all')
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000

# %%
data.dropna(how='all').iloc[6:8, [1, 2, 6, 9, 11, 12]]
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000

# %%
data.dropna(how='all').iloc[6:8, [0, 2, 6, 9, 11, 12]]
# Out:
#     0                      2   6   9     11     12
# 11 NaN  Велосипед "Спринтер"   шт   5  9000  45000
# 12 NaN    Велосипед "Малютка"  шт  10  3500  35000

# %%
table = data2.iloc[6:8, :].dropna(axis=1, how='all')

# %%
table
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000

# %%
table.to_csv("module3_table.csv")

# %%
table.to_excel("module3_table.xls")

# %%
table.to_excel("module3_table.xls", index=False)

# %%
writer = pd.ExcelWriter('module3_test.xlsx')  
table.to_excel(writer, index=False, sheet_name='Таблица')  
writer.save()

# %%
workbook = writer.book  
worksheet = writer.sheets['Таблица']

# %%
money_fmt = workbook.add_format({'bold': True})  
name_fmt = workbook.add_format({'color': 'red'})  
  
worksheet.set_column('E:F', 20, money_fmt)  
worksheet.set_column(1, 1, 20, name_fmt)
# Out:
# 0

# %%
table.to_excel(writer, index=False, sheet_name='Таблица')  
writer.save()

# %% [markdown]
# Какие еще параметры можно попробовать:
#
# border отвечает за границы столбца и может быть равен True или False;
#
# align отвечает за расположение данных внутри ячеек, например, center для настройки выравнивания по центру;
#
# fg_color отвечает за цвет фона, например, 'green', хотя можно передать и шестнадцатиричное значение, например, '#D7E4BC'.

# %%
writer = pd.ExcelWriter('module3_test.xlsx')  
table.to_excel(writer, index=False, sheet_name='Таблица')  
writer.save()  

workbook = writer.book  
worksheet = writer.sheets['Таблица'] 

money_fmt = workbook.add_format({'bold': True})  
name_fmt = workbook.add_format({'color': 'red'})  
  
worksheet.set_column('E:F', 20, money_fmt)  
worksheet.set_column(1, 1, 20, name_fmt)
