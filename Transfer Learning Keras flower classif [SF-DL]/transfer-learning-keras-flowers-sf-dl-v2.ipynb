# %% [markdown]
# # Transfer learning в решении задачи классификации цветов
# Датасет классификации цветов (http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) состоит из 102 видов цветов встречаемых в Великобритании. Для каждого класса есть от 40 до 258 примеров, чего мало для обучения с нуля:
# <img src="http://bennycheung.github.io/images/deep-transfer-learning-on-small-dataset/flower_train_samples_700.jpg" style="width:50%">

# %%
# !pip install tensorflow==2.1
# Out:
# Requirement already satisfied: tensorflow==2.1 in /opt/conda/lib/python3.6/site-packages (2.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.18.2)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.11.2)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.4.1)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (2.1.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.0.8)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (2.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.27.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (0.9.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.14.0)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (0.8.1)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (3.11.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (3.2.0)
# Requirement already satisfied: gast==0.2.2 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (0.2.2)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.1) (0.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.6/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (3.2.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.6/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.12.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.6/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.6/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.6/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (2.22.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.6/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (46.1.3.post20200330)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras-applications>=1.0.8->tensorflow==2.1) (2.10.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /opt/conda/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (4.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.24.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.6/site-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (3.1.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import scipy.io
import tarfile
import csv
import sys
import os


import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.models as M
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
import tensorflow.keras.callbacks as C
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import optimizers

from sklearn.model_selection import train_test_split

import PIL
from PIL import ImageOps, ImageFilter
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
# %matplotlib inline

print(os.listdir("../input"))
print('Python       :', sys.version.split('\n')[0])
print('Numpy        :', np.__version__)
print('Tensorflow   :', tf.__version__)
print('Keras        :', keras.__version__)
# Out:
# ['flower-dataset-102']
# Python       : 3.6.6 |Anaconda, Inc.| (default, Oct  9 2018, 12:34:16)
# Numpy        : 1.18.2
# Tensorflow   : 2.1.0
# Keras        : 2.2.4-tf

# %%
# Проверяем что у нас работает GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# Работаем уже с Tensorflow 2.1 но для воспроизводимости сохраним версии всех пакетов

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# # Setup

# %%
# В сетап выношу основные настройки, так удобней их перебирать в дальнейшем

EPOCHS               = 25
BATCH_SIZE           = 128
LR                   = 1e-3
VAL_SPLIT            = 0.2

CLASS_NUM            = 102
IMG_SIZE             = 128
IMG_CHANNELS         = 3
input_shape          = (IMG_SIZE, IMG_SIZE, IMG_CHANNELS)

DATA_PATH = '../input/flower-dataset-102/'
PATH = "../working/flower/"

# %%
# Setting seed for reproducibility
os.makedirs(PATH,exist_ok=False)

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)  
PYTHONHASHSEED = 0

# %% [markdown]
# # Data

# %%
# прочитаем все названия файлов прям из архива и таргеты к ним
def get_all_filenames(tar_fn):
    with tarfile.open(tar_fn) as f:
        return [m.name for m in f.getmembers() if m.isfile()]

df = pd.DataFrame()
df['Id'] = sorted(get_all_filenames(DATA_PATH+"102flowers.tgz"))
df['Category'] = scipy.io.loadmat(DATA_PATH+'imagelabels.mat')['labels'][0] - 1  # классы (0, 1, 2, ...)
df['Category'] = df['Category'].astype(str)

# %%
df.head(5)
# Out:
#                     Id Category
# 0  jpg/image_00001.jpg       76
# 1  jpg/image_00002.jpg       76
# 2  jpg/image_00003.jpg       76
# 3  jpg/image_00004.jpg       76
# 4  jpg/image_00005.jpg       76

# %%
df['Category'].value_counts()
# Out:
# 50    258
# 76    251
# 45    196
# 72    194
# 88    184
#      ...
# 20     40
# 6      40
# 33     40
# 44     40
# 0      40
# Name: Category, Length: 102, dtype: int64

# %%
df['Category'].nunique()
# Out:
# 102

# %%
print('Распаковываем картинки')
# Will unzip the files so that you can see them..
opened_tar = tarfile.open(DATA_PATH+"102flowers.tgz")
opened_tar.extractall(PATH)

print(os.listdir(PATH+'jpg')[:5])
# Out:
# Распаковываем картинки
# ['image_02200.jpg', 'image_00194.jpg', 'image_01278.jpg', 'image_04252.jpg', 'image_06860.jpg']

# %%
print('Пример картинок (random sample)')
plt.figure(figsize=(12,8))

random_image = df.sample(n=9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values

for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(PATH+path)
    plt.subplot(3,3, index+1)
    plt.imshow(im)
    plt.title('Class: '+str(random_image_cat[index]))
    plt.axis('off')
plt.show()
# Out:
# Пример картинок (random sample)

# %%
# убедимся что метки классов подгрузились верно
print('Пример картинок (random sample)')
plt.figure(figsize=(12,8))

random_image = df[df['Category']=='1'].sample(n=9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values

for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(PATH+path)
    plt.subplot(3,3, index+1)
    plt.imshow(im)
    plt.title('Class: '+str(random_image_cat[index]))
    plt.axis('off')
plt.show()
# Out:
# Пример картинок (random sample)

# %%
# как видим изображения имеют разный размер
image = PIL.Image.open(PATH+path)
imgplot = plt.imshow(image)
plt.show()
image.size
# Out:
# (667, 500)

# %% [markdown]
#  ## Stratify Split

# %%
# трейн / тест
train_files, test_files, train_labels, test_labels = \
    train_test_split(df['Id'], df['Category'], test_size=0.2, random_state=42, stratify=df['Category'])

train_files = pd.DataFrame(train_files)
test_files = pd.DataFrame(test_files)
train_files['Category'] = train_labels
test_files['Category'] = test_labels

train_files.shape, test_files.shape
# Out:
# ((6551, 2), (1638, 2))

# %%
train_files.head(5)
# Out:
#                        Id Category
# 2361  jpg/image_02362.jpg       42
# 512   jpg/image_00513.jpg       87
# 5969  jpg/image_05970.jpg       68
# 6251  jpg/image_06252.jpg       60
# 516   jpg/image_00517.jpg       87

# %%
train_files['Category'].value_counts()
# Out:
# 50    206
# 76    201
# 45    157
# 72    155
# 88    147
#      ...
# 26     32
# 6      32
# 44     32
# 33     32
# 0      32
# Name: Category, Length: 102, dtype: int64

# %%
test_files['Category'].value_counts()
# Out:
# 50    52
# 76    50
# 45    39
# 72    39
# 88    37
#       ..
# 66     8
# 6      8
# 2      8
# 33     8
# 0      8
# Name: Category, Length: 102, dtype: int64

# %% [markdown]
# ### Data augmentation

# %%
# Аугментация данных очень важна когда у нас не большой датасет (как в нашем случае)

train_datagen = ImageDataGenerator(rescale=1. / 255, 
                                    rotation_range = 50,
                                    shear_range=0.2,
                                    zoom_range=[0.75,1.25],
                                    brightness_range=[0.5, 1.5],
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %% [markdown]
# ### datagen

# %%
# "Заворачиваем" наши данные в generator

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_files,
    directory=PATH,
    x_col="Id",
    y_col="Category",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, 
    seed=RANDOM_SEED,)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_files,
    directory=PATH,
    x_col="Id",
    y_col="Category",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False, 
    seed=RANDOM_SEED,)
# Out:
# Found 6551 validated image filenames belonging to 102 classes.
# Found 1638 validated image filenames belonging to 102 classes.

# %%
from skimage import io

def imshow(image_RGB):
  io.imshow(image_RGB)
  io.show()

x,y = train_generator.next()
print('Пример картинок из train_generator')
plt.figure(figsize=(12,8))

for i in range(0,9):
    image = x[i]
    plt.subplot(3,3, i+1)
    plt.imshow(image)
    #plt.title('Class: '+str(y[i]))
    #plt.axis('off')
plt.show()
# Out:
# Пример картинок из train_generator

# %%
x,y = test_generator.next()
print('Пример картинок из test_generator')
plt.figure(figsize=(12,8))

for i in range(0,9):
    image = x[i]
    plt.subplot(3,3, i+1)
    plt.imshow(image)
    #plt.title('Class: '+str(y[i]))
    #plt.axis('off')
plt.show()
# Out:
# Пример картинок из test_generator

# %% [markdown]
# # Model

# %%
input_shape
# Out:
# (128, 128, 3)

# %%
model = M.Sequential()

# model layer 1
model.add(L.Convolution2D(128, (3, 3), input_shape=input_shape, activation='relu', padding='same',))
model.add(L.BatchNormalization())
model.add(L.Convolution2D(128, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())

# Pooling layer 1
model.add(L.MaxPooling2D(pool_size=(2,2)))
model.add(L.Dropout(0.2))

# model and pooling layer 2
model.add(L.Convolution2D(256, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())
model.add(L.Convolution2D(256, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())

model.add(L.MaxPooling2D(pool_size=(2,2)))
model.add(L.Dropout(0.3))

# model and pooling layer 3.
model.add(L.Convolution2D(512, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())
model.add(L.Convolution2D(512, (3, 3), activation='relu', padding='same',))
model.add(L.BatchNormalization())

model.add(L.MaxPooling2D(pool_size=(2,2)))
model.add(L.Dropout(0.3))


# Flattening
model.add(L.Flatten())

# Full connection
model.add(L.Dense(512, activation='relu'))
model.add(L.Dropout(0.25))
model.add(L.Dense(CLASS_NUM, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 128)     3584
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 128)     512
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 128)     147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 512)       2048
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               67109376
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 102)               52326
# =================================================================
# Total params: 71,745,254
# Trainable params: 71,741,670
# Non-trainable params: 3,584
# _________________________________________________________________

# %%
# сколько слоев
print(len(model.layers))
# Out:
# 22

# %%
len(model.trainable_variables)
# Out:
# 28

# %% [markdown]
# ## Fit

# %%
#LR=0.0001
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adamax(lr=LR), metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint('best_model.hdf5' , monitor = ['val_accuracy'] , verbose = 1  , mode = 'max')
earlystop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
callbacks_list = [checkpoint, earlystop]

# %%
scores = model.evaluate_generator(test_generator, steps=1, verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 1/1 [==============================] - 6s 6s/step - loss: 4.6261 - accuracy: 0.0078
# Accuracy: 0.78%

# %%
# Обучаем
history = model.fit_generator(
        train_generator,
        steps_per_epoch = train_generator.samples//train_generator.batch_size,
        validation_data = test_generator, 
        validation_steps = test_generator.samples//test_generator.batch_size,
        epochs = EPOCHS,
        callbacks = callbacks_list
)
# Out:
# Train for 51 steps, validate for 12 steps
# Epoch 1/25
# 50/51 [============================>.] - ETA: 1s - loss: 13.9533 - accuracy: 0.0308
# Epoch 00001: saving model to best_model.hdf5
# 51/51 [==============================] - 82s 2s/step - loss: 13.7918 - accuracy: 0.0308 - val_loss: 11.6411 - val_accuracy: 0.0124
# Epoch 2/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.9791 - accuracy: 0.0353
# Epoch 00002: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.9774 - accuracy: 0.0350 - val_loss: 6.0954 - val_accuracy: 0.0221
# Epoch 3/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.7306 - accuracy: 0.0361
# Epoch 00003: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.7287 - accuracy: 0.0357 - val_loss: 6.3006 - val_accuracy: 0.0111
# Epoch 4/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.6071 - accuracy: 0.0405
# Epoch 00004: saving model to best_model.hdf5
# 51/51 [==============================] - 80s 2s/step - loss: 4.6082 - accuracy: 0.0405 - val_loss: 6.5503 - val_accuracy: 0.0286
# Epoch 5/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.5381 - accuracy: 0.0445
# Epoch 00005: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.5342 - accuracy: 0.0445 - val_loss: 7.6709 - val_accuracy: 0.0299
# Epoch 6/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.5071 - accuracy: 0.0467
# Epoch 00006: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 4.5050 - accuracy: 0.0475 - val_loss: 9.2045 - val_accuracy: 0.0286
# Epoch 7/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.4660 - accuracy: 0.0545
# Epoch 00007: saving model to best_model.hdf5
# 51/51 [==============================] - 80s 2s/step - loss: 4.4665 - accuracy: 0.0542 - val_loss: 7.5370 - val_accuracy: 0.0312
# Epoch 8/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.4162 - accuracy: 0.0639
# Epoch 00008: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.4180 - accuracy: 0.0632 - val_loss: 5.0822 - val_accuracy: 0.0482
# Epoch 9/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.3541 - accuracy: 0.0693
# Epoch 00009: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.3507 - accuracy: 0.0691 - val_loss: 4.9518 - val_accuracy: 0.0527
# Epoch 10/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.2998 - accuracy: 0.0723
# Epoch 00010: saving model to best_model.hdf5
# 51/51 [==============================] - 80s 2s/step - loss: 4.2984 - accuracy: 0.0721 - val_loss: 4.6980 - val_accuracy: 0.0605
# Epoch 11/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.2807 - accuracy: 0.0764
# Epoch 00011: saving model to best_model.hdf5
# 51/51 [==============================] - 80s 2s/step - loss: 4.2791 - accuracy: 0.0771 - val_loss: 4.7517 - val_accuracy: 0.0703
# Epoch 12/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.2357 - accuracy: 0.0794
# Epoch 00012: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.2365 - accuracy: 0.0794 - val_loss: 4.3796 - val_accuracy: 0.0807
# Epoch 13/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.1958 - accuracy: 0.0847
# Epoch 00013: saving model to best_model.hdf5
# 51/51 [==============================] - 80s 2s/step - loss: 4.1906 - accuracy: 0.0859 - val_loss: 4.0528 - val_accuracy: 0.1237
# Epoch 14/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.1573 - accuracy: 0.0893
# Epoch 00014: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.1548 - accuracy: 0.0887 - val_loss: 4.0103 - val_accuracy: 0.1100
# Epoch 15/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.1225 - accuracy: 0.0977
# Epoch 00015: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 4.1244 - accuracy: 0.0967 - val_loss: 4.0152 - val_accuracy: 0.1257
# Epoch 16/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.0651 - accuracy: 0.0985
# Epoch 00016: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.0672 - accuracy: 0.0992 - val_loss: 3.9325 - val_accuracy: 0.1230
# Epoch 17/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.0413 - accuracy: 0.1015
# Epoch 00017: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.0435 - accuracy: 0.1014 - val_loss: 3.8735 - val_accuracy: 0.1439
# Epoch 18/25
# 50/51 [============================>.] - ETA: 1s - loss: 4.0078 - accuracy: 0.1145
# Epoch 00018: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 4.0092 - accuracy: 0.1141 - val_loss: 3.8455 - val_accuracy: 0.1478
# Epoch 19/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.9701 - accuracy: 0.1171
# Epoch 00019: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 3.9720 - accuracy: 0.1180 - val_loss: 3.8411 - val_accuracy: 0.1432
# Epoch 20/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.9540 - accuracy: 0.1145
# Epoch 00020: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.9513 - accuracy: 0.1146 - val_loss: 3.9114 - val_accuracy: 0.1413
# Epoch 21/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.9542 - accuracy: 0.1217
# Epoch 00021: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.9550 - accuracy: 0.1211 - val_loss: 3.7719 - val_accuracy: 0.1393
# Epoch 22/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.9293 - accuracy: 0.1199
# Epoch 00022: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 3.9267 - accuracy: 0.1205 - val_loss: 3.6870 - val_accuracy: 0.1693
# Epoch 23/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.8761 - accuracy: 0.1307
# Epoch 00023: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.8791 - accuracy: 0.1298 - val_loss: 3.7934 - val_accuracy: 0.1510
# Epoch 24/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.8666 - accuracy: 0.1250
# Epoch 00024: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.8634 - accuracy: 0.1252 - val_loss: 3.6103 - val_accuracy: 0.1745
# Epoch 25/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.8795 - accuracy: 0.1271
# Epoch 00025: saving model to best_model.hdf5
# 51/51 [==============================] - 77s 2s/step - loss: 3.8782 - accuracy: 0.1266 - val_loss: 3.6727 - val_accuracy: 0.1608

# %%
model.save('../working/model_last.hdf5')
model.load_weights('best_model.hdf5')

# %%
scores = model.evaluate_generator(test_generator, steps=1, verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 3.6800 - accuracy: 0.1484
# Accuracy: 14.84%

# %%
def plot_history(history):
    plt.figure(figsize=(10,5))
    plt.style.use('dark_background')
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'b', label='Training acc')
    plt.plot(epochs, val_acc, 'g', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()

    #plt.figure()
    plt.figure(figsize=(10,5))
    plt.style.use('dark_background')
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'g', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_history(history)

# %% [markdown]
# не хватило 25 эпох, продолжим...

# %%
LR=0.0001
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adamax(lr=LR), metrics=["accuracy"])
history = model.fit_generator(
        train_generator,
        steps_per_epoch = train_generator.samples//train_generator.batch_size,
        validation_data = test_generator, 
        validation_steps = test_generator.samples//test_generator.batch_size,
        epochs = EPOCHS,
        callbacks = callbacks_list
)
# Out:
# Train for 51 steps, validate for 12 steps
# Epoch 1/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.7746 - accuracy: 0.1412
# Epoch 00001: saving model to best_model.hdf5
# 51/51 [==============================] - 79s 2s/step - loss: 3.7702 - accuracy: 0.1414 - val_loss: 3.5310 - val_accuracy: 0.1986
# Epoch 2/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.6739 - accuracy: 0.1535
# Epoch 00002: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.6748 - accuracy: 0.1527 - val_loss: 3.5217 - val_accuracy: 0.1979
# Epoch 3/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.6353 - accuracy: 0.1544
# Epoch 00003: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.6336 - accuracy: 0.1549 - val_loss: 3.4504 - val_accuracy: 0.2129
# Epoch 4/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.5945 - accuracy: 0.1668
# Epoch 00004: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.5957 - accuracy: 0.1664 - val_loss: 3.4897 - val_accuracy: 0.1979
# Epoch 5/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.5851 - accuracy: 0.1628
# Epoch 00005: saving model to best_model.hdf5
# 51/51 [==============================] - 77s 2s/step - loss: 3.5892 - accuracy: 0.1630 - val_loss: 3.3835 - val_accuracy: 0.2103
# Epoch 6/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.5897 - accuracy: 0.1638
# Epoch 00006: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.5909 - accuracy: 0.1647 - val_loss: 3.4023 - val_accuracy: 0.2057
# Epoch 7/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.4971 - accuracy: 0.1743
# Epoch 00007: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.5026 - accuracy: 0.1730 - val_loss: 3.3588 - val_accuracy: 0.2077
# Epoch 8/25
# 50/51 [============================>.] - ETA: 1s - loss: 3.5236 - accuracy: 0.1733
# Epoch 00008: saving model to best_model.hdf5
# 51/51 [==============================] - 78s 2s/step - loss: 3.5221 - accuracy: 0.1741 - val_loss: 3.3704 - val_accuracy: 0.2129

# %%
model.save('../working/model_last.hdf5')
model.load_weights('best_model.hdf5')

# %%
scores = model.evaluate_generator(test_generator, steps=1, verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 1/1 [==============================] - 1s 781ms/step - loss: 3.3265 - accuracy: 0.2266
# Accuracy: 22.66%

# %%
plot_history(history)

# %%
# Clean PATH
import shutil
shutil.rmtree(PATH)
