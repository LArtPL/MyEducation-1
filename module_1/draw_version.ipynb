# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id     budget    revenue   original_title  \
# 679   tt0462465   50000000    7033683        Outlander
# 22    tt2126355  110000000  470490832      San Andreas
# 735   tt1564367   80000000  214918407  Just Go With It
# 1552  tt0433416   12000000   20138836     The Namesake
# 1729  tt0442933   70000000  195735876          Beowulf
#
#                                                    cast         director  \
# 679   Jim Caviezel|Sophia Myles|Jack Huston|Ron Perl...    Howard McCain
# 22    Dwayne Johnson|Alexandra Daddario|Carla Gugino...      Brad Peyton
# 735   Jennifer Aniston|Adam Sandler|Nicole Kidman|Ba...     Dennis Dugan
# 1552  Kal Penn|Tabu|Irrfan Khan|Sahira Nair|Jacinda ...        Mira Nair
# 1729  Ray Winstone|Angelina Jolie|Anthony Hopkins|Ro...  Robert Zemeckis
#
#                                                 tagline  \
# 679   It destroyed his world. He won't let it destro...
# 22    A rescue pilot survived an earthquake, this is...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
# imdb_id                 1889 non-null object
# budget                  1889 non-null int64
# revenue                 1889 non-null int64
# original_title          1889 non-null object
# cast                    1889 non-null object
# director                1889 non-null object
# tagline                 1889 non-null object
# overview                1889 non-null object
# runtime                 1889 non-null int64
# genres                  1889 non-null object
# production_companies    1889 non-null object
# release_date            1889 non-null object
# vote_average            1889 non-null float64
# release_year            1889 non-null int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 206.7+ KB

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

def get_profit(data):
    return data['revenue']-data['budget']

def genres_counter(data):
    genres_counter = pd.Series()
    for genres in data['genres'].str.split('|'):
        for genre in genres:
            if genre in genres_counter: genres_counter[genre] += 1
            else: genres_counter[genre] = 1
    return genres_counter

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '...'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
answers['1'] = data[data['budget'] == data['budget'].max()][
                    'original_title'].iloc[0]
data[data['budget'] == data['budget'].max()]['original_title'].iloc[0]
# Out:
# 'Pirates of the Caribbean: On Stranger Tides'

# %%
answers
# Out:
# {'1': 'Pirates of the Caribbean: On Stranger Tides'}

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = data[data['runtime'] == data['runtime'].max()][
                    'original_title'].iloc[0]
data[data['runtime'] == data['runtime'].max()]['original_title'].iloc[0]
# Out:
# 'Gods and Generals'

# %%
answers
# Out:
# {'1': 'Pirates of the Caribbean: On Stranger Tides', '2': 'Gods and Generals'}

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = data[data['runtime'] == data['runtime'].min()][
                    'original_title'].iloc[0]
data[data['runtime'] == data['runtime'].min()]['original_title'].iloc[0]
# Out:
# 'Winnie the Pooh'

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = data['runtime'].mean()
data['runtime'].mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = data['runtime'].median()
data['runtime'].median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале

# %%
answers['6'] = data[get_profit(data) == get_profit(data).max()][
                    'original_title'].iloc[0]
data[get_profit(data) == get_profit(data).max()]['original_title'].iloc[0]
# Out:
# 'Avatar'

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = data[get_profit(data) == get_profit(data).min()][
                    'original_title'].iloc[0]
data[get_profit(data) == get_profit(data).min()]['original_title'].iloc[0]
# Out:
# 'The Lone Ranger'

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = len(data[get_profit(data)>0])
len(data[get_profit(data)>0])
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
data_2008 = data[data['release_year']==2008]
answers['9'] = data_2008[get_profit(data_2008) == get_profit(data_2008).max()][
                        'original_title'].iloc[0]
data_2008[get_profit(data_2008) == get_profit(data_2008).max()][
            'original_title'].iloc[0]
# Out:
# 'The Dark Knight'

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
data_f12t14 = data[(data['release_year']>=2012)&(data['release_year']<=2014)]
answers['10'] = data_f12t14[get_profit(data_f12t14)==get_profit(
                            data_f12t14).min()]['original_title'].iloc[0]
data_f12t14[get_profit(data_f12t14)==get_profit(data_f12t14).min()][
            'original_title'].iloc[0]
# Out:
# 'The Lone Ranger'

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале

number_of_genres = genres_counter(data)         
answers['11'] = number_of_genres[
                    number_of_genres == number_of_genres.max()].index[0]
print(answers['11'])
# Out:
# Drama

# %% [markdown]
# ВАРИАНТ 2

# %%
pd.Series(data['genres'].str.cat(sep='|').split(sep='|')).value_counts().index[0]
# Out:
# 'Drama'

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
profit_counter = pd.Series()

profit_genres = genres_counter(data[get_profit(data) > 0])
answers['12'] = profit_genres[profit_genres == profit_genres.max()].index[0]
print(answers['12'])
# Out:
# Drama

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
directors = pd.Series(data['director'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
for director in directors.index:
    directors[director] = data['revenue'][data['director'].apply(lambda x:
                                True if director in x else False)].sum()
answers['13'] = directors.sort_values(ascending=False).index[0]
answers['13']
# Out:
# 'Peter Jackson'

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
data_action_films = data[data['genres'].apply(lambda x: True if 'Action' in x else False)]
directors = pd.Series(data_action_films['director'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
for director in directors.index:
    directors[director] = data_action_films['director'].apply(lambda x: True if director in x else False).value_counts().loc[True]
answers['14'] = directors.sort_values(ascending=False).index[0]
answers['14']
# Out:
# 'Robert Rodriguez'

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
data_2012 = data.query('release_year == 2012')
cast = pd.Series(data_2012['cast'].str.cat(sep='|').split('|'))
cast = cast.value_counts(ascending=False)
for actor in cast.index:
    cast[actor] = data_2012['revenue'][data_2012['cast'].apply(lambda x: True if actor in x else False)].sum()
answers['15'] = cast.sort_values(ascending=False).index[0]
answers['15']
# Out:
# 'Chris Hemsworth'

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
data_high_budget = data.query('budget > budget.mean()')
actors = pd.Series(data_high_budget['cast'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
for actor in actors.index:
    actors[actor] = data_high_budget['cast'].apply(lambda x: True if actor in x else False).value_counts().loc[True]
answers['16'] =actors.sort_values(ascending=False).index[0]
answers['16']
# Out:
# 'Matt Damon'

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
data_NCage = data[data['cast'].apply(lambda x: True if 'Nicolas Cage' in x else False)]
number_of_genres = genres_counter(data_NCage)         
answers['17'] = number_of_genres[
                    number_of_genres == number_of_genres.max()].index[0]
answers['17']
# Out:
# 'Action'

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
data_Paramount = data[data['production_companies'].apply(lambda x: True if 'Paramount Pictures' in x else False)]
answers['18'] = data_Paramount[get_profit(data_Paramount)==get_profit(data_Paramount).min()]['original_title'].iloc[0]
answers['18']
# Out:
# 'K-19: The Widowmaker'

# %%
data.head(5)
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# ...

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = data.groupby('release_year').sum()['revenue'].sort_values(ascending=False).index[0]
answers['19']
# Out:
# 2015

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
data_WBros = data[data['production_companies'].apply(lambda x: True if 'Warner Bros' in x else False)].copy()
data_WBros['profit'] = get_profit(data_WBros)
answers['20'] = data_WBros.groupby('release_year').sum()['profit'].sort_values(ascending=False).index[0]
answers['20']
# Out:
# 2014

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
data_month = data.copy()
data_month['month'] = pd.to_datetime(data['release_date']).dt.month
data_month['film'] = 1
answers['21'] = data_month.groupby('month').sum()['film'].sort_values(ascending=False).index[0]
answers['21']
# Out:
# 9

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
data_month = data.copy()
data_month['month'] = pd.to_datetime(data['release_date']).dt.month
data_month['film'] = 1
answers['22'] = data_month.groupby('month').sum()['film'].iloc[5:8].sum()
answers['22']
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
data_directors = data.copy()
data_directors['month'] = pd.to_datetime(data['release_date']).dt.month
data_directors = data_directors[(data_directors['month']<=2)|(data_directors['month']>=12)]
data_directors
directors_winter = pd.Series(data_directors['director'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
answers['23'] = directors_winter.index[0]
answers['23']
# Out:
# 'Peter Jackson'

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
films = pd.Series(data['production_companies'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
companies = films.copy()-films
for i in range(0,len(data)):
    for companie in (data.iloc[i]['production_companies'].split('|')):
        companies[companie] += len(data.iloc[i]['original_title'])
answers['24'] = (companies/films).sort_values().index[-1]
answers['24']
# Out:
# 'Four By Two Productions'

# %%
data_csymbols = data.copy()
data_csymbols['comp'] = pd.Series(data['production_companies'].str.split('|'))

# %%
pd.Series(data_csymbols['comp'])
# Out:
# 0       [Universal Studios, Amblin Entertainment, Lege...
# 1       [Village Roadshow Pictures, Kennedy Miller Pro...
# 2       [Summit Entertainment, Mandeville Films, Red W...
# 3           [Lucasfilm, Truenorth Productions, Bad Robot]
# 4       [Universal Pictures, Original Film, Media Righ...
#                               ...
# 1884    [Twentieth Century Fox Film Corporation, Donne...
# 1885                                    [New Line Cinema]
# 1886    [Universal Pictures, Capella International, KC...
# 1887    [Laurence Mark Productions, Columbia Pictures ...
# 1888                              [Warner Bros. Pictures]
# Name: comp, Length: 1889, dtype: object

# %%
type(data_csymbols['comp'][0])
# Out:
# list

# %%
'Village' in data_csymbols['comp'][1]
# Out:
# False

# %%
pd.Series(data_csymbols['comp'][1])
# Out:
# 0     Village Roadshow Pictures
# 1    Kennedy Miller Productions
# dtype: object

# %%
for i in range(0,len(data_csymbols)):
    data_csymbols['comp'][i] = pd.Series(data_csymbols['comp'][i])
# Out:
# C:\Users\PL\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
films = pd.Series(data_csymbols['production_companies'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
films
# Out:
# Universal Pictures                        173
# Warner Bros.                              168
# Paramount Pictures                        122
# Columbia Pictures                         117
# Twentieth Century Fox Film Corporation    109
#                                          ...
# Sid & Marty Krofft Pictures                 1
# 98 MPH Productions                          1
# Allspark Pictures                           1
# TelevisiÃ³ de Catalunya (TV3)               1
# Blackout Productions Inc.                   1
# Length: 1771, dtype: int64

# %%
companies = films.copy()-films
companies
# Out:
# Universal Pictures                        0
# Warner Bros.                              0
# Paramount Pictures                        0
# Columbia Pictures                         0
# Twentieth Century Fox Film Corporation    0
#                                          ..
# Sid & Marty Krofft Pictures               0
# 98 MPH Productions                        0
# Allspark Pictures                         0
# TelevisiÃ³ de Catalunya (TV3)             0
# Blackout Productions Inc.                 0
# Length: 1771, dtype: int64

# %%
for companie in companies.index:
    for x in data_csymbols[data_csymbols['production_companies'].str.contains(companie)]['original_title']: companies[companie] += len(x)
companies
# Out:
# C:\Users\PL\Anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Universal Pictures                        2578
# Warner Bros.                              2791
# Paramount Pictures                        2078
# Columbia Pictures                         2402
# Twentieth Century Fox Film Corporation    1799
#                                           ...
# Sid & Marty Krofft Pictures                 16
# 98 MPH Productions                          10
# Allspark Pictures                           21
# TelevisiÃ³ de Catalunya (TV3)                0
# Blackout Productions Inc.                    7
# Length: 1771, dtype: int64

# %%
symbols = companies/films
symbols.sort_values()
# Out:
# The Movie Network (TMN)                      0.000000
# Pacific Data Images (PDI)                    0.000000
# British Broadcasting Corporation (BBC)       0.000000
# Industrial Light & Magic (ILM)               0.000000
# Danmarks Radio (DR)                          0.000000
#                                              ...
# Sony                                       474.000000
# DreamWorks                                 475.333333
# Universal                                  910.333333
# Disney                                    1667.000000
# Twentieth Century Fox                     1892.000000
# Length: 1771, dtype: float64

# %%
films = pd.Series(data['production_companies'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
companies = films.copy()-films
for companie in companies.index:
    for x in data[data['production_companies'].str.contains(companie)]['original_title']: companies[companie] += len(x)
symbols = companies/films
symbols.sort_values()
# Out:
# C:\Users\PL\Anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Warner Independent Pictures (WIP)        0.000000
# British Film Institute (BFI)             0.000000
# Nouvelles Ã‰ditions de Films (NEF)       0.000000
# Flower Films (II)                        0.000000
# Dimension Films (US version)             0.000000
#                                          ...
# Sony                                   474.000000
# DreamWorks                             475.333333
# Universal                              910.333333
# Disney                                1667.000000
# Twentieth Century Fox                 1892.000000
# Length: 1771, dtype: float64

# %%
films = pd.Series(data['production_companies'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
companies = films.copy()-films
for companie in companies.index:##!.split('|')
    for x in data[data['production_companies'].str.contains(companie)]['original_title']: companies[companie] += len(x)
symbols = companies/films
symbols.sort_values()

# %%
data_length = data.copy()
data_length['title_length'] = data_length['original_title'].str.len()
films = data_length['title_length']
films = pd.Series(data['production_companies'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
films['Universal']
# Out:
# 3

# %%
a=['aa','bb']
'a' in a
# Out:
# False

# %%
data['original_title']
# Out:
# 0                             Jurassic World
# 1                         Mad Max: Fury Road
# 2                                  Insurgent
# 3               Star Wars: The Force Awakens
# 4                                  Furious 7
#                         ...
# 1884                                   X-Men
# 1885                      The Little Vampire
# 1886    The Adventures of Rocky & Bullwinkle
# 1887                              Hanging Up
# 1888                            The In Crowd
# Name: original_title, Length: 1889, dtype: object

# %%
companies = data.production_companies.str.cat(sep='|').split('|')
symbols = {c: [len(x) for x in data[data.production_companies.str.contains(c)].original_title] for c in companies}
symbols
# Out:
# {'Universal Studios': [14, 15, 17, 6, 18, 19],
#  'Amblin Entertainment': [14,
#   15,
#   31,
#   24,
#   35,
#   9,
#   28,
#   17,
#   24,
#   7,
#   9,
#   15,
#   15,
#   14,
#   17,
#   19,
#   6,
#   13,
#   20,
#   21,
#   12,
#   12,
#   34],
#  'Legendary Pictures': [14,
#   22,
#   8,
#   7,
#   12,
#   12,
#   8,
#   11,
#   14,
#   22,
#   8,
#   18,
#   12,
#   8,
#   14,
#   9,
#   19,
#   8,
#   8,
#   15,
#   9,
#   20,
#   12,
#   21,
#   19,
#   11,
#   12,
#   21,
#   21,
#   13,
#   13,
#   15,
#   17,
#   3],
#  'Fuji Television Network': [14, 10, 14],
#  'Dentsu': [14, 9, 10, 14, 14, 16, 14, 8, 10, 17, 24, 10, 16],
#  'Village Roadshow Pictures': [18,
#   17,
#   11,
#   10,
#   13,
#   16,
#   15,
#   14,
#   9,
#   14,
#   13,
#   15,
#   18,
#   45,
#   18,
#   43,
#   14,
#   9,
#   12,
#   11,
#   9,
#   16,
#   12,
#   16,
#   11,
#   9,
#   11,
#   34,
#   14,
#   16,
#   10,
#   19,
#   8,
#   28,
#   12,
#   22,
#   19,
#   12,
#   12,
#   16,
#   14,
# ...

# %%
symbols[0:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-13e5fd198da3> in <module>
# ----> 1 symbols[0:1]
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
films = pd.Series(data['production_companies'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
companies = films.copy()-films
for i in range(0,len(data)):
    for companie in (data.iloc[i]['production_companies'].split('|')):
        companies[companie] += len(data.iloc[i]['original_title'].split())
answers['25'] = (companies/films).sort_values().index[-1]
answers['25']
# Out:
# 'Four By Two Productions'

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = data[data['vote_average']>=data['vote_average'].quantile(0.99)]['original_title']
answers['26']
# Out:
# 9                                              Inside Out
# 28                                              Spotlight
# 34                                                   Room
# 118                                          Interstellar
# 119                               Guardians of the Galaxy
# 124                                            Big Hero 6
# 125                                    The Imitation Game
# 128                                             Gone Girl
# 138                              The Grand Budapest Hotel
# 155                              The Theory of Everything
# 177                                The Fault in Our Stars
# 283                                            Mr. Nobody
# 316                                              3 Idiots
# 370                                             Inception
# 496     The Lord of the Rings: The Fellowship of the Ring
# 599                                       The Dark Knight
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
df = pd.DataFrame([[1,2],[3,4]], columns=(['a','b']), index=['c','d'])
df
# Out:
#    a  b
# c  1  2
# d  3  4

# %%
df['a']['c']
# Out:
# 1

# %%
data.head(1)
# Out:
#      imdb_id     budget     revenue  original_title  \
# 0  tt0369610  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#              tagline                                           overview  \
# 0  The park is open.  Twenty-two years after the events of Jurassic ...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
#
#    vote_average  release_year
# 0           6.5          2015

# %%
data_pairs = pd.Series(data['cast'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
data_pairs = pd.DataFrame(data_pairs-data_pairs)
data_pairs
# Out:
#                    0
# Samuel L. Jackson  0
# Nicolas Cage       0
# Robert De Niro     0
# Matt Damon         0
# Bruce Willis       0
# ...               ..
# Joseph Fiennes     0
# Andy Buckley       0
# John Sharian       0
# Margaret Avery     0
# Deniz Akdeniz      0
#
# [3406 rows x 1 columns]

# %%
for actors in data['cast']:
    for actor in actors.split('|'):
        data_pairs[actor]
# Out:
# ['Chris Pratt', 'Bryce Dallas Howard', 'Irrfan Khan', "Vincent D'Onofrio", 'Nick Robinson']
# ['Tom Hardy', 'Charlize Theron', 'Hugh Keays-Byrne', 'Nicholas Hoult', 'Josh Helman']
# ['Shailene Woodley', 'Theo James', 'Kate Winslet', 'Ansel Elgort', 'Miles Teller']
# ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher', 'Adam Driver', 'Daisy Ridley']
# ['Vin Diesel', 'Paul Walker', 'Jason Statham', 'Michelle Rodriguez', 'Dwayne Johnson']
# ['Leonardo DiCaprio', 'Tom Hardy', 'Will Poulter', 'Domhnall Gleeson', 'Paul Anderson']
# ['Arnold Schwarzenegger', 'Jason Clarke', 'Emilia Clarke', 'Jai Courtney', 'J.K. Simmons']
# ['Matt Damon', 'Jessica Chastain', 'Kristen Wiig', 'Jeff Daniels', 'Michael PeÃ±a']
# ['Sandra Bullock', 'Jon Hamm', 'Michael Keaton', 'Allison Janney', 'Steve Coogan']
# ['Amy Poehler', 'Phyllis Smith', 'Richard Kind', 'Bill Hader', 'Lewis Black']
# ['Daniel Craig', 'Christoph Waltz', 'LÃ©a Seydoux', 'Ralph Fiennes', 'Monica Bellucci']
# ...

# %%
import

# %%
combinations('ABCD', 2)

# %%
companies = pd.Series(data_high_budget['production_companies'].str.cat(sep='|').split('|')
                         ).value_counts(ascending=False)
companies = pd.DataFrame(companies)
companies.columns=['films']
for companie in companies.index:#wrong answer
    companies[companie] = data['production_companies'].apply(lambda x: True if companie in x else False).value_counts().loc[True]

companies

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-4504a5dd134c> in <module>
# ----> 1 combinations('ABCD', 2)
#
# NameError: name 'combinations' is not defined

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '...', '2': '...'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
